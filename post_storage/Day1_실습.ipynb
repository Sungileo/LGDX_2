# %% [markdown]
# ---
# title: "Day1 실습"
# author: "박성일"
# date: "2024-08-06"
# description: "미니프로젝트 Day1"
# format:
#   html:
#     toc: true
#
# ---

# %% [markdown]
# # ◆ 0. 데이터 불러오기

# %%
import pandas as pd

# 한글 크롤링 -> LG씽큐 앱 리뷰 데이터
data = pd.read_csv("data/한글 크롤링.csv")

# datetime으로 바꾸는건데 안해도됨됨
year = [i[0] for i in data["Date"].str.split("년")]
month = [i[1].split("월")[0].strip().zfill(2) for i in data["Date"].str.split("년")]
day = [i[1].split("월")[1].replace("일","").strip().zfill(2) for i in data["Date"].str.split("년")]
data['Date'] = pd.to_datetime(["-".join(i) for i in zip(year,month,day)])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rc('font', family='NanumGothicCoding')
mpl.rcParams['axes.unicode_minus'] = False
review_per_date = pd.DataFrame(data['Date'].value_counts()).sort_values('Date')

plt.figure(figsize=(18,5))
plt.plot(review_per_date)
plt.xlabel("Date")
plt.ylabel("리뷰 수")
plt.title("Review count per date")

plt.show()

# %% [markdown]
# # ◆ 1. 데이터 전처리하기
# * 1.1. 특수문자 및 숫자 제거
# * 1.2. 의미없는 짧은 글 제거

# %% [markdown]
# ### 1.1. 특수문자 및 숫자 제거
#     *정규표현식 사용

# %%
import re
from tqdm import tqdm
pattern = r"[^a-zA-Z0-9가-힣\s\.\?\!]"

new_review = []

for i in tqdm(data['Review']):
    text = re.sub(pattern, "", i)
    new_review.append(text)

data['Review_clean'] = new_review
data.head()
# Out:
# 100%|██████████| 6280/6280 [00:00<00:00, 626506.89it/s]
#         Date            Name  Score  \
# 0 2020-01-24             홍현주      3
# 1 2020-01-07              쌤쌤      3
# 2 2020-01-08    Nicholas Jun      1
# 3 2020-01-24        Hong KIM      1
# 4 2020-01-22  byung-hyun cho      3
#
#                                               Review  like  \
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...     2
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...     0
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...     0
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...     0
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...     0
#
#                                         Review_clean
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...

# %% [markdown]
# ### 1.2. 의미없는 짧은 글 제거

# %%
df = data.drop([i for i,j in enumerate(data["Review_clean"]) if len(j) <10])
df.head()
# Out:
#         Date            Name  Score  \
# 0 2020-01-24             홍현주      3
# 1 2020-01-07              쌤쌤      3
# 2 2020-01-08    Nicholas Jun      1
# 3 2020-01-24        Hong KIM      1
# 4 2020-01-22  byung-hyun cho      3
#
#                                               Review  like  \
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...     2
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...     0
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...     0
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...     0
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...     0
#
#                                         Review_clean
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...

# %% [markdown]
# # ◆ 2. 데이터 형태소 분리하기
# * 2.1 불용어적용 및 형태소 분리
# * 2.2 데이터 프레임에 추가

# %% [markdown]
# ### 2.1. 불용어적용 및 형태소 분리
#     *제공되는 한국어 불용어 파일 사용(ko-stopwords.csv)

# %%
from konlpy.tag import Okt
okt=Okt()
#원하는 태그 추출 & 불용어 제거
stopword_df = pd.read_csv('data/ko-stopwords.csv')
stopwords = list(stopword_df['stopwords'])

def okt_pos_tagging(string):
    pos_words = okt.pos(string, stem=True, norm=True) # norm은 약간의 오타 교정

    tagged_list=[]
    for word, tag in pos_words:
        if tag in ['Noun', 'Adjective', 'Verb']:
            if word not in stopwords:
                tagged_list.append(word)
    if len(tagged_list) == 0 :
      tagged_list.append("None")
    return tagged_list

# %% [markdown]
# ### 2.2 데이터 프레임에 추가

# %%
df['tagged_review'] = df['Review_clean'].apply(okt_pos_tagging)
df.head()
# Out:
#         Date            Name  Score  \
# 0 2020-01-24             홍현주      3
# 1 2020-01-07              쌤쌤      3
# 2 2020-01-08    Nicholas Jun      1
# 3 2020-01-24        Hong KIM      1
# 4 2020-01-22  byung-hyun cho      3
#
#                                               Review  like  \
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...     2
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...     0
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...     0
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...     0
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...     0
#
#                                         Review_clean  \
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...
#
#                                        tagged_review
# 0  [시스템, 에어컨, 대다, 연결하다, 격, 제어, 사용, 에어컨, 기능, 공기청정기...
# 1  [인덕션, 제어, 용, 사용, 끄다, 전용, 건, 좋다, 격, 제어기, 능이, 계속...
# 2  [위례, 살다, 신혼, 부부, 공기청정기, 자다, 연동, 걸리다, 않다, 문제, 김...
# 3  [세탁기, 연결하다, 정도, 세상, 쓰레기, 연결, 번거롭다, 사용성, 까다롭다, ...
# 4  [건조, 완료, 후, 에어, 리플, 레쉬, 원격, 추가, 수, 건조, 완료, 후, ...

# %%
df["n_pos"] = [len(i) for i in df['tagged_review']]
pos_per_review = df.groupby("n_pos").count()
plt.figure(figsize=(12,5))
plt.bar(pos_per_review.index, pos_per_review['tagged_review'])
plt.xlabel("n_pos")
plt.xticks(range(0,250,5))
plt.ylabel("count")
plt.title('Pos count per Review')
plt.xlim(0,100)

plt.show()

# %% [markdown]
# # ◆ 3. 벡터화
# * 3.1 doc2vec 준비(문서의 순서 매기기)
# * 3.2 doc2vec 학습시키기
# * 3.3 벡터 값 데이터 프레임에 추가

# %% [markdown]
# ### 3.1 doc2vec 준비
#     - word2vec은 단어 하나를 하나의 vector화
#     - doc2vec은 문서 하나를 하나의 vector화

# %% [markdown]
# ![KakaoTalk_20240806_121018535.png](attachment:KakaoTalk_20240806_121018535.png)

# %%
from gensim.models import doc2vec
from gensim.models.doc2vec import TaggedDocument
# doc2vec
tagged_corpus_list = []

for i, token in enumerate(df.tagged_review):
    tag = "document {}".format(i)
    tagged_corpus_list.append(TaggedDocument(tags=[tag], words = token))
print('문서의 수 :', len(tagged_corpus_list))
# Out:
# 문서의 수 : 4061

# %% [markdown]
# ### 3.2 doc2vec 학습시키기
#     <model 하이퍼파라미터 값>
#     # vector_size : 생성할 문서 벡터의 크기
#     # alpha: 모델 학습시 초기 학습률 0.025는 일반적으로 사용됨
#     # min_alpha: 학습 과정에서 alpha 값을 이 값으로 줄여나가게 됩니다
#     # window : 문맥 윈도우 크기, 주변 몇개의 단어의 문맥을 고려하여 학습하는가

# %%
#doc2vec모델
model = doc2vec.Doc2Vec(vector_size=100, alpha=0.025, min_alpha=0.025, window=8)

# Vocabulary 빌드
model.build_vocab(tagged_corpus_list)

# Doc2Vec 학습
#epochs가 너무 많이 돌아가면 과적합의 가능성 / 학습속도 느려짐
model.train(tagged_corpus_list, total_examples=model.corpus_count, epochs=5)

# %% [markdown]
# ### 3.3 벡터 값 데이터 프레임에 추가

# %%
vector_list = []

for i in tqdm(range(len(df))):
    doc2vec = model.dv["document {}".format(i)]
    vector_list.append(doc2vec)

df['vector'] = vector_list
# Out:
# 100%|██████████| 4061/4061 [00:00<00:00, 444855.40it/s]

# %%
df.head()
# Out:
#         Date            Name  Score  \
# 0 2020-01-24             홍현주      3
# 1 2020-01-07              쌤쌤      3
# 2 2020-01-08    Nicholas Jun      1
# 3 2020-01-24        Hong KIM      1
# 4 2020-01-22  byung-hyun cho      3
#
#                                               Review  like  \
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...     2
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...     0
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...     0
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...     0
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...     0
#
#                                         Review_clean  \
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...
#
#                                        tagged_review  n_pos  \
# 0  [시스템, 에어컨, 대다, 연결하다, 격, 제어, 사용, 에어컨, 기능, 공기청정기...     48
# 1  [인덕션, 제어, 용, 사용, 끄다, 전용, 건, 좋다, 격, 제어기, 능이, 계속...     40
# 2  [위례, 살다, 신혼, 부부, 공기청정기, 자다, 연동, 걸리다, 않다, 문제, 김...     58
# 3  [세탁기, 연결하다, 정도, 세상, 쓰레기, 연결, 번거롭다, 사용성, 까다롭다, ...     32
# 4  [건조, 완료, 후, 에어, 리플, 레쉬, 원격, 추가, 수, 건조, 완료, 후, ...     45
#
#                                               vector
# 0  [-0.039117035, 0.004292973, -0.009551597, -0.0...
# 1  [-0.02055112, -0.025830656, -0.023246385, -0.0...
# 2  [-0.025872136, 0.0043870504, 0.013973244, -0.0...
# 3  [-0.013279051, 0.007602067, 0.0013019999, -0.0...
# 4  [-0.024529207, -0.027414525, -0.025277354, -0....

# %% [markdown]
# # ◆ 4. 병합 계층적 클러스터링
# * 4.1 ward 기준으로 덴드로그램 그려보기
# * 4.2 실루엣 지수 확인해서 토픽 갯수 정하기
# * 4.3 가장 적절한 클러스터링 갯수 df에 삽입

# %% [markdown]
# ### 4.1 ward 기준으로 덴드로그램 그려보기

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(list(df['vector']), 'ward')

plt.figure(figsize=(15, 9)) #인치
dendrogram(linked,
            orientation='top',
            distance_sort='descending',
            show_leaf_counts=True)
plt.show()

# %% [markdown]
# ### 4.2 실루엣 지수 확인해서 토픽 갯수 정하기

# %%
from sklearn.metrics.cluster import silhouette_score
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=2,linkage='ward')
cluster_labels = cluster.fit_predict(list(df['vector']))
silhouette_avg = silhouette_score(list(df['vector']), cluster_labels)

# %%
n_clutser=[]
clustering_score = []
for i in tqdm(range(2, 30)):
    cluster = AgglomerativeClustering(n_clusters=i,linkage='ward')
    cluster_labels = cluster.fit_predict(list(df['vector']))
    score = silhouette_score(list(df['vector']), cluster_labels)

    n_clutser.append(i)
    clustering_score.append(score)
# Out:
# 100%|██████████| 28/28 [00:23<00:00,  1.19it/s]

# %%
plt.figure(figsize=(10,4))
plt.plot(n_clutser, clustering_score)
plt.xticks(range(30))
plt.axis()

plt.show()

# %%
result = pd.DataFrame({'n_cluster':n_clutser, 'score':clustering_score})
result
# Out:
#     n_cluster     score
# 0           2  0.542237
# 1           3  0.245795
# 2           4  0.251566
# 3           5  0.151918
# 4           6  0.143093
# 5           7  0.122442
# 6           8  0.103175
# 7           9  0.102937
# 8          10  0.097405
# 9          11  0.097901
# 10         12  0.095335
# 11         13  0.087329
# 12         14  0.087945
# 13         15  0.089619
# 14         16  0.091740
# 15         17  0.086913
# 16         18  0.087017
# 17         19  0.088125
# 18         20  0.084448
# 19         21  0.072394
# 20         22  0.070165
# 21         23  0.070084
# 22         24  0.070172
# 23         25  0.065616
# 24         26  0.063334
# 25         27  0.063038
# 26         28  0.062941
# 27         29  0.062989

# %% [markdown]
# ### 4.3 가장 적절한 클러스터링 갯수 df에 삽입

# %%
cluster = AgglomerativeClustering(n_clusters=6,linkage='ward')
cluster_labels = cluster.fit_predict(list(df['vector']))

df['cluster'] = cluster_labels
df.head()
# Out:
#         Date            Name  Score  \
# 0 2020-01-24             홍현주      3
# 1 2020-01-07              쌤쌤      3
# 2 2020-01-08    Nicholas Jun      1
# 3 2020-01-24        Hong KIM      1
# 4 2020-01-22  byung-hyun cho      3
#
#                                               Review  like  \
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...     2
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...     0
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...     0
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...     0
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...     0
#
#                                         Review_clean  \
# 0  시스템에어컨 5대 연결해서 원격제어로 사용중입니다. 에어컨 기능은 공기청정기능까지 ...
# 1  인덕션 제어용으로 사용하려고 하는데 끄는 전용인건 좋은데 원격제어기능이 계속 꺼져야...
# 2  위례 사는 신혼 부부입니다. TV랑 공기청정기는 잘 연동시켰습니다. 오래 걸리지도 ...
# 3  세탁기 된다고 해서 연결했는데 놀라울 정도로 세상 쓰레기에요. 연결은 번거롭고 사용...
# 4  건조완료후 에어리플레쉬를 원격으로도 추가할 수 있도록 건조완료후 원격제어를 off하...
#
#                                        tagged_review  n_pos  \
# 0  [시스템, 에어컨, 대다, 연결하다, 격, 제어, 사용, 에어컨, 기능, 공기청정기...     48
# 1  [인덕션, 제어, 용, 사용, 끄다, 전용, 건, 좋다, 격, 제어기, 능이, 계속...     40
# 2  [위례, 살다, 신혼, 부부, 공기청정기, 자다, 연동, 걸리다, 않다, 문제, 김...     58
# 3  [세탁기, 연결하다, 정도, 세상, 쓰레기, 연결, 번거롭다, 사용성, 까다롭다, ...     32
# 4  [건조, 완료, 후, 에어, 리플, 레쉬, 원격, 추가, 수, 건조, 완료, 후, ...     45
#
#                                               vector  cluster
# 0  [-0.039117035, 0.004292973, -0.009551597, -0.0...        5
# 1  [-0.02055112, -0.025830656, -0.023246385, -0.0...        4
# 2  [-0.025872136, 0.0043870504, 0.013973244, -0.0...        2
# 3  [-0.013279051, 0.007602067, 0.0013019999, -0.0...        4
# 4  [-0.024529207, -0.027414525, -0.025277354, -0....        4

# %% [markdown]
# # ◆ 5. 해석하기:TF-IDF
# * 문서 내에서 어떤 단어가 얼마나 중요한지를 평가하는 데 사용되는 방법
# * 5.1 TF-IDF 계산
# * 5.2 데이터프레임으로 만들고 정렬하기

# %% [markdown]
# ### 5.1 TF-idf 계산
# * 각 클러스터 마다 tfidf가 높은 워드들 찾기
# * 각 클러스터들을 하나의 문서로 가정하여 tf-idf 값 추출

# %%
from collections import Counter
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#각 클러스터들을 하나의 문서로 가정
all_document=[]
for i in df['cluster'].unique():

    #각 클러스터들을 하나의 문서로 가정
    #데이터 프레임에서 추출하여 tagged_Review를 join을 이용하여 합치기
    pos_tagged = df[df['cluster']==i].tagged_review

    #포스태깅된 데이터들을 공백 기준으로 하나로 합쳐 하나의 document로 생성
    cluster_document=''
    for pos in pos_tagged:
        doc = ' '.join(pos)
        cluster_document += doc

    all_document.append(cluster_document)

# %%
all_document
# Out:
# ['시스템 에어컨 대다 연결하다 격 제어 사용 에어컨 기능 공기청정기 능 앱 모드 청정 모드 없다 냉방 습 송풍 난방 자동 만 청정 없다 리모컨 청정 누르다 앱 송풍 데 앱 송풍 선택 청정 않다 리모컨 송풍 청정 킬수 원격 송풍 청정 에어컨 공기 청정 난방 청정 사용스마트 진단 기능 처음 사용 해봤다 비콘 뭔가 주고받다 기계 음 나다 폰 진단 상태 표시 완전 신기하다 자동차 진단 체 크기 갖다 대다 듯공기 청정 기능 잇다 벽 걸이 에어컨 큐 켜다 하나요 스탠드 청기 버튼 잇다 놈 전원 켜다 송풍 켜다 청 버튼 누르다 큐 송풍중 나오다 리모콘 청 버튼 누르다 큐 청정 나오다 스탠드 처음 페이지 청 버튼 필요하다 해 참고 리모콘 청 버튼 누르다 큐 송풍 꺼지다 잇다스타 이르다 바지 패딩 어플 깔다 선택 개 짜증 깔다 번거러움 폰 연결 힘들다 어렵다 연결 오류 지우다 다시 연결하다 하니 돼다 화가 남 누가 개발 통 터지다 암호 기호 별 아깝다 움맞벌이 예약 세탁 기능 자다 활용 홈페이지 건의 남기다 예약 위로 수 맞추다 불편하다 들다 오후 완료 세탁 예약 지금 오전 오전 기다리다 후 후 완료 예약 설정 아예 먀음 좋다 그게 안되다 단위 추가 해주다 안되다 요 오전 깜빡 오전 생각 이나 기다리다 여간 불편하다 아니다이전 글 업데이트 이후 구형 스마트폰 베가 아이언 어풀 실행 불가 현상 풀 초기 로고 강제 팅기다 나가다 업데이트 이후 어플 로고 화면 넘어가다 제품 정보 다운로드 시도 수초 무 반응 후 강제 팅기다 나가다 재 설치 해도 마찬가지 증상 개 정도 제품 어플 오류 때문 수일 제대로 활용 못 빠르다 수정 부탁드리다 업데이트 이후 여전하다 어플 강제 종료 증상 이제 슬슬 지치다 가다 그냥 최근 버젼 안드로이드 폰 새롭다 구입 더 빠르다 생각 듭니 더 이상은 글 쓰다 그렇다세탁기 돌리다 완료 폰 알림 오다 갑자기 낮 완료 세탁기 오밤중 완료 되어다 알리다 외부 나가다 어플 전원 킬 수가 없다 기능 추가 해주다 완료 알람 뒷북 치다 상관없다 습 닷격 제어 기능 좋다 표준 코스 코스 종류 별로 선택 표준 코스 안 세탁 헹굼 탈수 정해지다 원하다 선택 안되다 세탁 헹굼 탈수 개별 사용자 원하다 세부 선택 좋다 기능 모르다 가요코드 제로 사용 도면 나서다 그려지다 도면 영역 영역 분리 방 영역 영역 붙다 그린 도면 영역 합치다 기능 영역 영역 수정 넣다 편집 좋다로보킹 사용 중 앱 청소 구역 지정 기능 없다 중국 들다 기능 앱 통 찾다 청소 구역 맵핑해 보여주다 좋다 애쓰다 만들다 지도 활 용도 없다 지도 청소 금지 구역 청소 구역 지정 수 좋다이제 기능 이전 내용 업데이트 더 좋아지다 드럼세탁기 건조기 사용 오늘 아침 통 돌이 사용 알림 오다 마지막 알림 앱 들어가다 상단 종 모양 아이콘 누르다 확인 푸시 알림 전혀 알다 앱 실행 블루투스 도대체 자동 켜지다 건지다도움 한국어 표시 항상 핸드폰 보다 아니다 신호 음 상황 놓치다 버리다 경우 많다 음성 언어 제공 해주다 차다 좋다 냉장 고문 열리다 건조 완료 되어다 밥솥 음성 언어 제공 해주다 없다세탁기 건조기 구매 후 설치 연동 안되다 공유기 옆 하나요 세탁실 제일 가깝다 미터 근처 계속 튕겨 핸폰 연동 려고 자꾸 세탁기 건조기 연결 후 다시 모바일 데이터 연결하다 인터넷 제일 끄다 싶다 기기 연동 시도 빼다 인터넷 자다 잡히다 플러그 뽑다 새롭다 해도 여전하다 그렇다 허비하다 진 빠지다좋다 항상 와이파이 오다 리 모트 앱 기능 켜지다 상태 좋다 세탁기 전원 켜다 해 관련 설정 기억 전원 동시 적용 되어다 해 알림 서비스 편하다 글구 알림 서비스 바라다 메세지 창 띄우다 좋다 소리 듣다 알다 알림 창 알리 소리 정도 알리다 기능 메시지 출력 선택 좋다 불편하다 점 스마트 리 모트 켜다 걸리다 번 누르다 하니 전체 만족하다 스마트 리 모트 기능 사용 않다 알림 기능 맘 들다 방 세탁기 알림 음 들다 추다 날 진행 보로 세탁기 베란다 가다 곤욕 정말 편리하다 기능 스마트 패드 지원 좋다드럼세탁기 미니 워시 스타 이르다 로봇청소기 공기청정기 건조기 격 필요하다 등록 필요없다 원격 관리 공기청정기 불가 맞벌이 퇴근길 미리 작동시키다 싶다 전원 켜다 출근 전기요금 나오다 싶다 사용 많다 알다건조기 사용 에너지 모니터링 메뉴 들어가다 당연하다 월간 일간 소비전력 건조기 용이 별 소비전력 그렇다 전혀 없다 단순하다 건조 횟수 평균 게 글씨 인 디케이터 뿐 평균 수치 전혀 정보 없다 제대로 정보 표기 바 표기 않다 낫다 더 개선 설계 바라다원격 연결 끊어지다 불평 많다 도대체 개선 안되다 안되다 플러그 뺏다 꽂다 임시 방편 해결 며칠 지나다 들어가다 보다 원격 연결 끊어지다 도대체 뭐 어플 수동 플러그 뺏다 꽂다 계속 이용에어컨 온도 습도 실시간 알다 켜다 끄다 용량 통계 알다 스마트 체크 편하다 세탁기 태그 온 방식 코스 다운로드 기능 세탁 체크 스마트 체크 좋다 불편하다 점 한가지 제품 상태 확인 생각 로딩 걸리다 무한 로딩 강제 종료 재 시작 불편하다 인터넷 와이파이 단말기 거리 미터 에어컨 경우 운전 시작 않다 전원 꺼지다 상태 온도 설정 바람 모드 추천 운전 버튼 활성화 되어다 기능 쓸다 없다 에어컨 기능 없다 건지다 에어컨 추천 운전 항목 추천 운전 없다 가다 뜨다 두번째 기기 상태 정보 앱 들어가다 않다 위젯 확인 되어다 좋다 앱 들어가다 번거롭다 마지막 앱 실행 쓰다 않다 블루투스 활성화 블루투스 필요하다 태그 온 읽다 쓰기 사용자 직접 활성화 쓰다 거나 유도 좋다개편 이후 에어컨 현재 전력량 데이터 못 읽다 버그 발생 에어컨 가동 현재 전력량 표시 데이터 참조 일간 주간 월간 집계 현재 불가능하다 사용자 입장 전략 량 정보 파악 중요하다 신속하다 대응 요청 드리다오다 연결하다 사운드 바광 블 연결 사용 음향 소거 버튼 눌렸을때 화면 음향 소거 아이콘 표시 음향 소거 안되다 외부 음향 기계 연결 시 음향 소거 적용 업데이트 해주다 등록 제품 순서 변경 해주다 지금 마지막 등록 제품 제일 위 올라가다 가장 쓰다 제품 위 올리다 순서 변경 옵션 만들다 좋다청청기 대하 로보킹 건조기 정수기 사용 이름 설정 영어 수 음 좋다 구글 홈 미니 제품 영어 연동 중 닉네임 설정 영어 안되다 구글 홈 컨트롤 안되다 청정기 오염 일정 수치 자동 운전 수 설정 일정 수치 이하 멈 추다 수 좋다 추천 운 앱 알림 오지 별 의미 느껴지다 바쁘다 알림 받다 화나다 별도 기계 구입 만들다 수 자체 설정 수 가장 편리하다 제품 사용자 구매력 높이다 수오늘 낮 갑자기 앱 실행 뒤 에어컨 들어가다 인터페이스 바뀌다 어제 해도 실시간 전력소비량 확인 수 이제 단위 로만 확인 수 바꿈 버러지 상황 도무지 이해 가지다 않다 정시 써다 기록 후 기록 보다 바뀌다 개발자 월급 치다 받다 부끄럽다 해 제발전 세탁기 구입 앱 사용 일반 통 돌이 세탁기 그렇다 세부 물 높이 설정 안되다 탁시 헹굼 탈수 횟수 못정 헹굼 탈수 기능 없다 부분 아쉽다 세탁 완료 알림 연락 오다 점 좋다 더 발전 되어다 세부 설정 가능하다 좋다세탁기 건조기 연동 사용 스마트 큐 계정 구글 홈 미니 연동 사용 중간 중간 상태 확인 음성 명령 자다 세탁 건조 완료 스마트폰 푸다 쉬 알림 오니 집 사실 무용지물 요 알림 구글 홈 스마트 스피커 음성 받다 수 업데이트 부탁드리다자다 사용 건의 사항 스케쥴 제어 별로 자동 끄다 켜다 에너지 세이브 용도 스마트폰 분활 화면 안되다 들다 공기청정기 미세먼지 현재 지역 미세먼지 차이 화면 비교 보고 싶다 분활 화면 적용 힘드다 날씨 화면 미세먼지 초미세먼지 상태 나타내다 좋다달 로보킹 사용 생각 화나다 샤오미 보다 곱절 비싸다 제품 인지도 세계 기업 못 만들다 겁 청소 미치다 사람 처럼 여기저기 갈피 못자다 돌아다니다 의자 밀고 다니다 벽체 헤딩 가다 가다 샤오미 써다 보고 제품 써다 비교 청소기 앞 샤오미 처럼 범퍼 만들다 레이저 센서 운영 자다 인지도 카메라 센서 말다 열 받다 청소기 보다 바보 생각 들다 로봇 청소기 맵 개선 줄다 청소 어디가 청소 안되다 실시간 확인세탁기 제품 격 제어 핸드폰 동작 그렇다 헹굼일때 물 높이 변경 변경 안되다 격 제어 의미 전원 키 못 격 제어 연결 중간 물 높이 변경 대체 용도  ...
#  '인덕션 제어 용 사용 끄다 전용 건 좋다 격 제어기 능이 계속 꺼지다 야하다 이유 궁금하다 전원 켜다 격 제어 누르다 전원 꺼지다 전 격 제어 유지 좋다 켜다 경우 밖 제어 격 제어 가능 꺼지다 끌 수 없다 위함세탁기 연결하다 정도 세상 쓰레기 연결 번거롭다 사용성 까다롭다 단독 기능 아예 불가능하다 세탁기 가다 전원 켜다 원격 누르다 야하다 크다 어른 애기 보행기 억지로 타고 헤헤 거 보다 차 사다 거건조 완료 후 에어 리플 레쉬 원격 추가 수 건조 완료 후 격 제어 말다 격 제어 시 건조 완료 건조 부족하다 경우 종종 에어 리플 레쉬 추다 격 제어 사용 시 건조 완료 후 격 제어 되어다 풀 편하다 상태 유지 프로그램 개선 줄다업데이트 이후 공기청정기 휴대폰 켜다 끄다 무조건 휴대폰 끄다 꺼지다 청 꺼지다 않다 띵띵띵 울리다 표기 업데이트 이전 폰 켜다 청 끄다 문제 없다엔지니어 정말 한심하다 보이다 업데이트 약관 동의 다시 제품 사라지다 예전 첫 등록 사라지다 공기청정기 다시 살아나다 외 퓨리 케어 냉장고 세탁기 건조기 에어컨 개 개 다시 등록 합 다시 연결 상태 복원 안되다 이르다 소리 나오다 개발 돈 받다 아니다 돈 받다 식 일해 유니크 계정 기기 등록 정보 그대로 지금 계정 연결 바뀌다 식이 데이터 중복 쌓이다 낭비 계시다 요즘 이렇다 개발 쥬니어 데리다 만들다 합 아니다 인력 많다 협업 안되다 계정 연동 명 만들다 계정 연동 꼬이다 만들다좋다 이동식 청청기 퓨리 케어 미니 연결 안되다 가요 이동식 공기 청청 기도 연결 싶다 연결 않다 슬프다어플 도 켜다 끄다 컨트롤 가능하다 좋다 현재 에어컨 건조기 인덕션 세탁기 많다 가전 이용 컨트롤 많다 않다 건조기 경우 격 제어 버튼 누르다 가능하다 더욱 개선 기대하다집안 가전 간단하다 진단 편리하다 자다 쓰다 와이파이 애 서든 컨트롤 좋다원격 조정 가능하다 편하다 지다 청정기 전원 켜다 끌 수 스타 이르다 안 되어다 불편하다처 가다 공기 청정기 사용 기능 취침 모드 설정 안되다 취침 모드 설정 가능하다 해주다건조기 건조 끝나다 파악 외 쓸모 없다 건조기 격 제어 직접 가다 건조기 켜다 원격 제어 조작 그렇다 쓰다유용하다 자다 쓰다 안드로이드 업데이트 이후 모바일 데이타 로봇청소기 연결 해제 되어다 나오다 폰 오류 건지다 모르다서버 응답 돼다 모피 코스 돌리다 안되다 요즘 스터일러 돌 일일이 없다 건조기 자다 쓰다 스타 이르다 짜증나다 다시 앱 깔다 나아지다 요 복잡하다 그렇다 못공기청정기 사용 중 예전 연결 업데이트 제품 스마트폰 연결하다 말 나오다 연결 안되다 빠르다 문제해결 부탁드리다계속 서버 오류 나오다 사용 지금 서버 응답 없다 대다 도대체 응답 답 패딩입는 철 패딩 기능 다운로드 받다 사용 못 짜증나다서버 연결 오류 계속 뜨다 음 끝나다 알람 오다 조치 아예 먹통 달도 더 된거 셋팅도못 확인공기청정기 구매 연결 성공하다 기기 제어 화면 안 들어가다 와이파이 번 켜다세탁기 전원 직접 기기 켜 두다 격 제어 설정 앱 컨트롤 가능하다 불편하다 앱 전원 조절 외출 시 세탁 시작로봇청소기 문제 모르다 자꾸 해제 그것 집 서도 작동 가능하다 점 편하다네트워크 오류 라면 종료 갑자기 이렇다핸드폰 세탁기 건조기 전원 켜다 끄다 해주시 건조기 건조 끝나다 환기 모드 실행 코스 만들다아주 편리하다 원격 조종 가능하다 집 밖 자다 사용세탁기 소음 자꾸 나서다 걱정 스마트 진단 받다 간단하다 해결기계 기계 소통 해주다 의사소통 신기하다 고맙다집 와이파이 밖 조절 가능하다 굿 집 대기 상태 수시 확인가능 굿쓸모 없다 로그인 로그아웃 등록 거 다사 라지 사용 불편하다좋다 블루투스 강제 켜다 그만두다설치 자다 제품 연결 자다서버 연결 실패 버그 달 안고 징앱 켜다 끄다 단순 기능 외로 상황 맞추다 작동 기능 따다 리모콘 자다 쓰다직접 건조기 장소 가지 않다 건조 진행 상태 알다처음 와이파이 잡다 걸리다 이후 늣업데이트 기존 등록 내용 사라지다세탁기 뚜껑 닫다 기능 좋다차다 편리하다 료금 나오다 걱정가전제품 쓰시 띵큐 연결하다 편하다 좋다격 제어 켜다 누르다 전원 켜 놓다 격 제어 임연결 정보 결과물 통보 기능 좋다블루투스 켜다 느리다좋아지다 기기 자꾸 떨어지다 다시 붙이다 야하다 거 해결 해주다에어컨 정수기 공기청정기 스타 이르다 연결하다 잘쓰다 오늘 세탁기 바꾸다 등록 앱 연결하다 세탁기 아이콘 보이지 않다 업데이트 전 내 등록 않다 가전 아이콘 보이다 오늘 보다 내 등록 제품 보이다 무리 찾아보다 새롭다 등록 없다건조기 남다 바뀌다 않다 그대로 임편하다 나쁘다 않다 세탁 끝나다 알람 주다 만해 좋다 에어컨 켜다 끄다 좋다등록 편리하다 좋다어플 알림 기능 없어지다 업데이트 전 세탁기 건조기 스타 이르다 끝나다 어플 알림 오다 사용 좋다 갑자기 알림 없어지다 어플 보다 푸다 쉬 알림 왜안 뜨다 건지다 모르다 원래 안 뜨다 바뀌다 건지다 건지다 궁긍유용하다 자다 쓰다 퓨리 케어 평형 쓰다 필터 관리 지나다 계속 필터 수명 프로 남다 청소 기적 해주다 그렇다 뫄르겠 부분 빼다 동작 듯 유용하다가전제품 연동 자다사용 무척 편리하다원격 편하다구형 안드로이드 업데이트 달이 넘다 안되다 기기 개 가량 등록 되어다 달 넘다 쓰다 못 걸리다 예전 버전 다운 받다 수 어플 구분 올리다 구형 폰 쓰다 사람 무시 겁좋다 스마트 진단 에어컨 미리 점검 해봤다스마트 크다 늘다 앱 전원 제어 채널 변경 안되다 밖 공기청정기 제어 작동 좋다 늘다 제어 안되다 연결 끊기다 래서야 큐 인공 지능 뭘 앱 도대체 뭘 쩌 지다 모르다 개선 필요스타 이르다 동작 한참 전 끝나다 휴대폰 보다 분 남다 뜨다 현상 핸드폰 제어 안되다어플 문제 문의 서버 응답 계속 없다어플 연결 후 사용 음량 조절 채널 변경 안되다 숫자 변경 입력 안되다 버그연결 기기 소프트웨어 업데이트 좋다여지 껏 동생 쓰다 앱 깔다 사용 정말 혁신 요 늘 빨래 자주 돌리다 입장 세탁실 가지 않다 알다 주다 편리하다 좋다 밖 세탁 기능 기계 치인 입장 쉬다 다가가다 좋다 다행스마트 진단 완전 편리가전제품 폰 진단 신기하다연결하다 고생 예약 먼저 코스 선택 시작 눌럿다 빨래 시작 버리다 세탁기 건조기 전원 키 원격 누르다 사용 가능 보다 가다버전 다운로드 좋다 기다 사용 쫌 어렵다 스타 이르다 연결 자다 안되다편리하다 정검 좋다쪼금더 버그 수정과 상세 조절 기능 초기 연결 어렵다 다운로드 프로그램 없다스토어 게 새롭다 들어오다 업뎃했다 뭔가 들어가다 보다 청기 필터 소모품 쭉 파네 전 사다 아쉽다 편리하다세탁기 원격 되어다 별 개 세탁기 정해진 코스 아쉽다 격 제어 버튼 누르다 놓다 가전 만족하다와이파이 설정 기능 편하다 공기 청정도 아주 냄새 잡다 상쾌하다종합 관리 좋다생각 편리 냉장고 항시 온도 표시 없다 아쉽다 온도 지금 인지 알다 좋다서버 연결 실패 계속 뜨다 앱 꺼지다모델 사용 앱 간단 컨트롤 사용 시 뒤 가기 없다 불편하다 개선 해주다 로봇청소기정말 좋다 어플 추가 위젯 기능 제공 해주다 좋다 항상 앱 들어가다 가전 작동시키다 꽤 번거롭다핸드폰 연동 되어다 기능 여러가지 기능 격 제어 수 편리하다 좋다 적극 추천인공 지능 홈 보드 연결하다 로봇청소기 음성 안되다유용하다 사용 서버 응답 없다 계속 그렇다 복구처음 앱 시작 느리다실행 블루투스 자동 켜다 블루투스 자동 켜지다 끄다 설정 메뉴 만들다잘쓰다 며칠 전 서버 연결 안되다 대요집 들어가다 맞추다 세탁기 돌리다 건조기 돌아가다 상황 보다 바깥 보다 나가다 완전 편리하다날씨 걱정 빨래 수 좋다 건조하다 좋다 건조 끝나다 알림 받다 차다 좋다서버 응답 없다 오류 지속 발생 답 없다 엘 화에어컨 미리 켜둘 수 좋다 세탁기 전원 꺼지다 상태 전원 켜다 작동시키다 수 금상첨화 겠다어플 하나로 격 제어 기능 세탁 편리하다 꼭 써다 보다업뎃 이후 로봇청소기 선택 영역 청소 버튼 사라지다 청소 금지 영역 설정 안되다 사실 청소 말르다 임연동 좋다편리하다 느리다 구글 홈 연동 불안정하다인식 반응 동작 늦다편리하다 자꾸 등록 제품 리스트 사라지다 버그 개선 해주다접속 자주 끊기다 실행 시 와이파이 블루투스 자동 켜지다 툴바 형태 실행 없다폰 알림 오니 좋다직접 가다 세탁 남다 계속 확인 안해 편하다전원 원격 켜다 수  ...
#  '위례 살다 신혼 부부 공기청정기 자다 연동 걸리다 않다 문제 김치냉장고 서버 연결 끊기다 노티 팝업 뜨다 안되다 앱 실행 자체 불가능 더욱 골 때리다 건 전화기 네비게이션 영역 알림 누르다 앱 접속 돼다 앱 실행 안되다 종료 비 세이 션 영역 실행 중 뜨다 앱 실행 안되다 상단 네비게이션 들어가다 큐 쓰다 자고 접수 해결 방법 알다안드로이드 버튼 없다 등록 단계 자체 넘어가다 달 넘다 아이폰 등록 엘지 문의 놓다 전혀 답변 없다 개선 안되다 내 임원 어플 관리 놈 목 아지 삼성 이기다 쯧쯧 다시다 엘지 가전 사다앱 동시 기다리다 메시지 가까이 나오다 기네 리모컨 기능 빼 버리다 때문 라면 간단 모드 고급 모드 나누다 선택 해도 좋다공기청정기 등록 단계 제품 연결 준비 제품 버튼 어쩌구 단계 넘어가다 버튼 화면 데 없다 뭐 폰 데이터 그냥 잡다 잡수다 어플 엘지 제품 편하다 사용 하라 어플 확률 더 크다 보이공기 청정기 연결 하나요 유튜브 보다 공기 청정기 와이파이 연결하다 버튼 버튼 없다 넘어가다 않다 바꾸다 와이파이 아이디 영어 숫자 조합 와이파이 비밀 번호 없애다 하나요냉장고 구입 연결 시도 제품 연결 준비 단계 누르다 활성화 연결 진행 안되다네트웍 잡다 걸리다 초보자 잡기 어리다 대체로 만족하다 나쁘다 않다 가전 가다 중역시 답 정말 완벽하다 앱 가지 아쉽다 스팀 빼다 건조 안되다 아쉽다 추가 해주다 감사하다안녕하다 앱 들어가다 제품 보이다 제품 직관 보다 전원 켜지다 꺼지다 상태 보다 상태 바 제품 옆 보이 더 좋다 생각 듭니와이파이 연결 진짜 불안하다 날 갑자기 연결 끊기다 기도 짜증나다사용 깔끔하다 영문 나오다 국문 바꾸다 게 외국 거주 자동 영문 뜨다에어컨 연동 쓰다 여러 시도 해도 연결 않다 문의 드리다 답변 없다 쓰다 은지 말르다앱 푸시 확인 확인 댓글 달다 앱 푸시 설정 되어다 업뎃이후 기기 삭제 후 다시 설정 와이파이 재 설정 해주다 푸시 들다 세탁기자다 쓰다 갑자기 계정 등록 더니 제품 정보 나르다 가다 통 세척 푸시 알림 알다 확인 불편하다본체 코드 꼽히다 스마트폰 전원 켜다 시작 격 제어 의미 없다기정 청기 메뉴 일별 스케줄 정해 특정시 꺼지다 켜다 등록 계속 스케줄 작동 좋다지다 중 오케이 구글 공기청정기 켜다 똥 차다 켜지다 굳다 브랜드 구분 곳 등록 좋다서버 응답 연결 서버 연결 실패 나중 다시 시도 해보다 나중 대체 건 그냥 사용 스타 이르다 패딩 돌리다 보다한번 설정 핸드폰 블루투스 자동 활성화 좋다 안좋다 기도앱 업데이트 사용 청소기 화면 보이지 않다 세부 설정 들어가다 확인 불편하다겔 쓰다 앱 로딩 시 계속 팅기다 예전 적 늘다 전혀 패치 시 적용 해주다어플 깔다 시도 진동 울리다 오우 아주 대단하다뭔가 모자라다 예컨데 세탁 끝나다 세탁 끝나다 말로 알다 그렇다 센스 가다 없다 아쉽다 따다업데이트 난 뒤 서버 연결 자체 안되다 빠르다 조치 바라다 상당하다 불편하다빨래 보다 섬유 유연제 남다 넣다 보다 항상 보고 타이머 맞추다 어플 타이머 기능 좋다서버 연결 실패 달 도대체 해결 해주다 겁 화나다필터 관리 누르다 깨지다 현상 달 째다 정안 합외출 청소기 격조 정도 카메라 살펴보다 좋다핸폰 제어 안되다 요 세탁기 서다 전원 누르다 와이파이 키 격 제어 누르다 그다음 방 오다 핸폰 제어 소용데이터 통신 끄다 연결 프로세스 불편 함인터넷 연결 티비 어플 자동 검색 추가 되어다 자다 사용 중 티비 켜다 후 연결 해제 자주 뜨다 장치 삭제 후 재 검색 하니 검색 안되다 거서버 연결 안되다 어플 꺼지다순간 어플 알림 오지 않다 와이파이 설정 정상 어플 내 알림 설정 핸드폰 노트 드럼세탁기 건조기 알림 오지 않다 알림 안되다 기능 일시 정지 코스 선택 은 원인 요자다 서버 연락 없다 안되다 청기 에어컨 미리 켜다 좋다 알다 문제 리플 달다 서버 연락 없다 글 아예 리플 안다 해결 책 중이 연구 알다코스 선택 후 개별 설정 셋팅 가능하다 전원 켜다 격 제어 연결하다 표준 세탁 맞추다 앱 셋팅들 비 활성화 돼다 수정 불가하다 다시 한번 확인 해보다 관련 사진 올리다 싶다 기선 안되다 메일 보내다 요중반 자꾸 까먹다 큐 좋다 능이 땡큐 엘지편하다 쓸리다 깔다 앱 접근 꺼지다 뭡처음 제품 식이 느리다 점 아쉽다서버 응답 없다 몇번 지우다 세로 깔다 마찬가지 안정 성과 버그 수정 겁 질문 선택 답변 때문 그렇다 제대로 답변 주시앱 시작 블루투스 기능 자동실행 자동실행 안 해주다 공기 청정기 경우 앱 실행 가능하다 정수기 경우 추다 수량 확인 가능하다 청정기 뭘 수가 없다 제품 써다 보다 않다 패스엘지 건조기 원격 겁 건조 돌리다 전원 꺼지다 전원 지면 원격 무용지물 원격 전원 킬수있 건조 종료 후 상태 차다로봇 청소기 엘지 쓰다 다행 아니다 모르다 연결 안되다 쓰레기 어플 제어 계속 클릭 차다 업데이트 바보 되어다 느낌 좋다 쫌에어 프라이 기능 타입 오븐 렌 지다 관련 메뉴 선택 검색 안되다 베제 벽 걸이 에어컨 리모컨 공기 청정 단독 사용 안되다 모델 기능 재 점검 필요하다 연동 스피커 외 오다 구글편리하다 핸폰 격 제어 완전 신세전 버전 자다 쓰다 지금 버전 건조기 연결 안되다 연결 창 간다 음 건조기 와이파이 버튼 누르다 깜빡이다 아무 반응 없다휘센 에어컨 사용 느리다 차다 데 업데이트 열대야 취침 모드 사라지다 가요 없어지다 자다 환하다 켜다 불편하다 자다 정각 켜다 팅 밤 아예 라이트 들어오다 좋다 숲속 바람 모드 샤워 모드 차이다 뭐모든 기기 신혼 살림 구입 한지 약 개월 정도 스마트 큐 편하다 앱 설치 후 와이파이 등록 정말 와이파이 등록 제대로 돼다 허다 술 짝 없다 페이지 읽다 제대로 돼다 금보 앱 보안 개선 도데 체 뭘 건지다 그렇다 자다 야하다 아니다 넘다 실망 스럽다통 돌이 세탁기 연결하다 전원 꺼지다 격 제어 안되다 그냥 세탁기 가다 손꾸락 누르다 좀더 효과 좋다 심심하다앱 요구 권한 전화 위치 정보 부여 꽤 찝찝하다 무겁다 앱 추가 에어컨 온라인 아니다 상태 기존 사용 용량 확인 불가능하다 에어컨 본체 끄다 기능 리모컨 앱 없다 무척 불편하다올해 스텐드 에어컨 구입 해성 스마트 띵큐 앱 연결 사용 중 연결 해제 주 반복 적 번 연결 안되다 와이파이 아니다 참고 다이슨 공기 청정기 쓰다 에어컨 연결 해제 되어다 연결 안되다 앱 문제 인지 에어컨 문제 인지티비 김치냉장고 정수기 로봇청소기 등록 잘쓰다 날 갑자기 어플 화면 티비 빼다 없어지다 제품 정상 등록 되어다 어플 화면 사라지다 해결 방법 알다대부분 전자제품 사용 스마트 크다 등록 기분 좋다 방 없다 등록 표시 한참 아무렇다 동작 없다 나가다 들어오다 등록 되어다 제품 등록 진 빠지다세탁 알람 오다 에너지 모니터링 나오다 최근 코스 뜨다 최근 사용 횟수 조회 불가 건조기 정상 조회 앱 삭제 후 다시 설치 똑같다 제품 삭제 해도 똑같다앱 느리다 제어 기능 적다 기능 치다 실제 폰 제어 잇다 기능 제한 손 직접 기계 만지다 경우 많다요즘 시대 공기청정기 마음 든든하다서버 대한 응답 없다 며칠 전 뜨다 아무렇다 공지 없다 관련 리뷰 답글 달 않다 참고 이용 자임서버 응답 없다 자꾸 꺼지다 가전제품 다운로드 코스 이용 덕분 패딩 돌리다 기다리다 야하다 건지다 그렇다 수정 해주다오류 드럽다 나다 연결 끊어지다 로그아웃 다시 로그인 연결 어플 느리다 터지다 에어컨 한번 온도 조정 세월 결리다 느리다 속 터지다 리모컨 찾다 직접 누르다 빠르다 연결 안정 최악 어플 동성 구려 어플 속도 느리다 엘지 뭐합 중소기업 못 어플 수준 가지 가전 먹기 바쁘다어제 서버 연결 안되다 공지 연결 안되다 아기 키우다 자다 쓰다 공지 안되다 속 터지다업데이트 후 다시 리뷰 써다 제품 순서 변경 전 요청 적용 되어다 좋다 변경 위해 몇번 삭제 후 다시 등록 위로 올리다 기존 정보 삭제 이제 그렇다 필요 없다 좋다 계속 발전 바라다 엘지 믿다 사람계정 네이버 구글 간편 회원 가입 안 건가 자꾸 회원 가입 역 없다 전 계정 가지 처음 어렵다별 개도 아깝다 티브로드 셋탑 연결하다 스마트 채널 버튼 먹히다 볼륨 조정만 예전 리 모트 좋다매일 점검 합 접속 느리다 리액션 속도 쓸다 정도 속도 개선 시급하다 점검 개선 안되다 래서야 지금 에어컨 끄다 연결 해제 계속 돌아가다 ...
#  '스타 이르다 사용 와이파이 등록 격 제어 사용 갑자기 와이파이 연결 않다 앱 기기 삭제 재 등록 버튼 깜빡 거리 데 앱 단계 넘어가다 않다 바지 관리 기능 사용 못 와이파이 확인 핸드폰 재부팅 앱 재 설치 다해 보다 안되다 앱 문제 스타 이르다 인지 실망에어컨 연결 돼다 제품 존재 않다 다시 연결하다 메세지 뜨다 다시 연결 제품 정보 주고받다 중 그대로 벽 걸이 추가 스탠드 사라지다 집안 가전 연결하다 달 걸리다 타 청 기다 쉬다 연결 쉬다 빠르다 연결하다 순 없다세탁기 물 선택 돼다 좋다 전원 켜지다 돼다 좋다 수건 한번 돌리다 거품 거품 검색 해보다 이슈 더 수건 게 건지다 설치다 설명 해주다세탁기 건조기 사용 전원 기능 없다 딱하다 쓸모 없다 가다 자동 버리다 기능 아쉽다 냉장고 딱하다 쓸다 일이 없다연결 안되다 제품 네트워크 변경 안되다 앱 업데이트 만들다 네트워크 변경 단계 넘어가다 바꾸다 말다 가이드 나오다 넘어가다 아예 없다 뭘 합갑자기 로그인 더니 등록 가구 삭제 와이파이 연결 안되다 아니다 잘만 사용 로그인 등록 돼다 제품 삭제 돼다 다시 설정 뜨다 않다 뭡편리하다 자다 사용 아쉽다 세탁기 전원 직접 켜다 점 키 나서다 격 모드 설정 점 아쉽다 집 서도 전원 켜다 격 제어 수 날 오다독서실 시스템 에어컨 사용 업데이트 뜨다 등록 기기 사라지다 기존 업데이트 후 기기 연결 해제 일로 고객 센터 연락 일도 이제 지겹다 그냥 원격 적외선 리모컨 쓰다 좋다사다 와이프 사용 다시 등록 하나요 삼성 구성원 등록 하니 등록 제품 그대로 옮기다 엘지 그렇다 기능 없다 가요잘쓰다 날 메인 화면 등록 제품 없다 뜨다 다시 제품 연결하다 등록 등록 되어다 그렇다 뭐 가문 젠 가요여지 껏 자다 서버 연결 안되다 뜨다 건조기 냉장고 연결 자다 되어다 공기청정기 연결 안되다 서버 접속 자다 안되다 계속 가전 교체 스마트 기능 이용 수 없다 가요세탁기 건조기 사용 자꾸 네트워크 불안전 원격 안되다 앱 그냥 꺼지다 전 자다 써다 요즘 불편하다네트워크 연결 할하 않다 고치다 껀가 거 뜨다 앱 꺼지다 쓸다 없다앱 문제 네트웍 연결 안되다 고생 새롭다 설치 후 자다 사용 사용 편하다앱 실행 와이파이 자동 키 요 처음 제품 등록 이외 와이파이 자동 못키 설정 없다유용하다 써다 어플 날 실행 서버 응답 없다 강제 종료 실행 않다 뭘 문제 해결 수 자세하다 답변 줄다작동 로봇청소기 연결 청소 끝나다 나다 연결하다 제로 뜨다 버리다 다이어리 보다 청소 시작 없다휴대전화 더 디테 컨트롤 수 좋다 로봇청소기 처럼 어플 맵 청소 경로 확인 그렇다 기능 추가 좋다아니다 갑자기 안되다 제품 다시 등록 세탁기 등록 스타 이르다 등록 사용 안되다 업데이트 나서다 뭐 모르다 차다 거지 만들다업데이트 내용 안정 개선 나빠지다 싶다 전 건조기 연결 자다 되어다 서버 응답 없다 계속 뜨다 어플 닫히다 건지다 모르다좋다 잘쓰다 개선 사항 몇몇 잘쓰다서버 연결 안되다 뜨다 스타 이르다 앱 실행 기능 사용 못 빠르다 개선 요청공기청정기 미세먼지 수치 별 일별 트랜드 보다 해주다 좋다 지금 수치 나오다 불편하다그닥 전원 켜다 제품 곳 가다 직접 켜다 어플 사용 궂 어플 제품 앞 핸드폰 사용전원 꺼지다 알림 소리 나다 무음 설정알림 설정 없다 광고 거부 불가 속도 느리다 답변 주다 개 추가최고 정말 편하다 사용 연결 자다 고사 용하다 편하다핸드폰 제어 가능하다 습도 율 물이 들어가다 칸 수도 나오다 더 좋다 바뀌다 좋다 욥건조기 시작 걸리다 사용 기록 표시 되어다세탁 건조기 연동 자다 사용 세탁 건조 끝나다 알다 넘다 좋다스타 이르다 태그 선택 누르다 안되다 글 누르다 헷갈리다 수정 되어다 좋다테블릿 설치 에어컨 예약 온도 조절 좋다알림 자다 오다 앱 켜다 서버 응답 않다 자동 종료 개월 응답 서버 응답 서버 서버아주 자다 활용 와이파이 연결 더 빠르다 좋다삼성 앱 실행 집 오다 삼성 공기청정기 엘지 확실하다 앱 실행 속도 더 느리다실행 후 제품 검사 느리다 속도 개선 해 줄다세탁기 완료 소리 자다 들다 자꾸 확인 핸드폰 알림 오다 좋다제품 등록 안되다 계속 공유기 비밀번호 오류 뜨다업데이트 로봇청소기 와이파이 연결 안되다어플 불편하다 어플 실행 아니다 위젯 사용 리모콘 대용앱 켜다 자동 와이파이 켜다 옛날 앱 아니다에어컨 건조기 연결하다 사용 아주 편하다키 끄다 예약 가능하다 절약 더 도움 주다 보다 편리하다복잡하다 않다 간단하다 연결하다 보다 간결하다 좋다외출 원격 조작 매우 편하다 진짜 잘만 앱 인정쓰레기 돼다 자다 쓰다 앱 업데이트 후 뭐 연결 안되다 앱 종료 노답 짜증나다아주 편리하다 사용 불편하다 없다불편하다 와이파이 연결 안되다 시도이제 설치 사용 유용하다 사용 좋다 능이스스로 셀프 진단 가능하다 편리하다 좋다제품 상태 자동 진단 케어 해주다 차다 편리하다 믿다서버 연결 안되다 오류 다운로드 코스 선택 사용 싶다 못 해결연결 쉬다 편리하다 사용 가능하다순간 세탁기 건조기 완료 알림 알다연결하다 걸리다 표시 더 좋다편리하다 와이파이 연결하다 어려움 좋다세탁기 교체 처음 알 되어다 세탁 진행 사항 마침 알림 편하다서버 응답 없다 어플 꺼지다폰 예약 설정 가능하다여러 가전 등록 자다 사용자다 사용 집 나오다 공기청정기 끄다 않다 나오다 기세 나오다 공기청정기 사다 좋다 자다 사용 좋다 하루연결 어렵다 사용 편하다여름 에어컨 연동 아주 자다 써다 최근 습하다 에어컨 틀다 보다 실행 등록 기기 없다 나오다 없다 다시 등록 시도 등록 기기 나오다 대체 가요 전혀 스마트 못 거 해결 책 알다스타 이르다 돌리다 서버 응답 없다 나오다 코스 많다 뭐함 일일 다운 받다 삭제 완전 번거롭다 움 지금 상태 론 다운로드 코스 사용 사용자 응답 없다 문의 거 뉴스 뜨다 조치 임집 삼성 에어컨 공기청정기 엘지 세탁기 건조기 로봇청소기 가전제품 개 어플 이용 어플 차이 나다 삼성 에러 진행 반면 엘지 어플 안되다저번 서버 응답 없다 앱 종료 버리다 이렇다 밑 리뷰 이렇다 증상 빈번 개선 생각 없다 신건 빠르다 해결 바라다 앱 전혀 스마트 않다업데이트 이후 서버 연결 실패 팝업창 뜨다 강제 종료 아예 사용 수가 없다 해결 방법 부탁드리다 재 설치 해도 마찬가지 앱 이용 자체 안되다자다 안되다 메뉴 전혀 맞다 않다좋다 먼지 없다 집안 기대 해보다자꾸 서버 연결 안되다 꺼지다 버리다서버 응답 없다 만 지금 주 업데이트 계속 이르다 확인 제품 앱 종료 크다 문제 아니다처음 괜찮다 지금 장난 아니다 계속 서버 연결 안되다 꺼지다 삭제 다시 괜찮다 깔다 지금 순간 켜다 않다 연결 안되다 알람 계속 뜨다 터 지게어플 재 설치 와이파이 잡다 등록 국가 계정 등록 제품 뜨다 건조기아니다 대체 공기청정기 와이파이 연결 응답 없다 해도 연결 해제 그렇다 미치다 해결 겁 제품 구매 폰 번 격 해보다 후 써다 보다 관리 건지다 이르다 겨 요새지금 접속 안되다 가요 올여름 일이 빠르다 확인 부탁드리다자주 끊기다 최악 정말 거 안되다 넘다 사용 돈 아깝다 카페 대다 넘다 사용 해편하다 기능 더 추가 되어다 해서버 점검 업데이트 나다 연결 해제 연결 되어다 조절 안되다 무인 가게 원격 난방 켜다 통제 불능 송풍 돌아가다 춥다 난리치다서버 연결 안되다 나오다 예전 느리다 자만 쓸다 수 재미있다 서버 제품 정보 받다 리스트 뜨다 서버 연결하다 없다 팝업 뜨다 앱 종료 수 없다 웃기다 티비 리모콘 작동 더 말 안되다 아이디 로그인 새롭다 등록 해보다 해도 뭘 선택 겨를 서버 연결하다 수 없다 뜨다 매우 버전 태블릿 보다 파이 버전 안드로이드 제대로 호환 않다 보이다공기청정기 원격 틀다 어플 오류 나다 안되다 진짜 짜증나다서버 응답 없다 뜨다 아무 기능 쓸다 수 없다 조치 답변 뭐 건지다 다운로드 코스 쓰다 은지건조 끝나다 알 여주 좋다업데이트 후 알림 표시 좋다 기존 폰 바꾸다 알림 오다 문제 데이터 삭제 재 설정 해결 돼다 백업 걸 그대로 복원 기존 폰 쪽 알림 가나 보다며칠 전 건조기 연결 해제 다시 연결하다 어제 사용 오늘 들어가다 보다 건조기 에어컨 냉장고 없어지다 등록 기기 없다 뜨다 에어컨 재 등록 려고 등록 안되다 하나요업뎃 제품 자주 연결 안되다 연결하다 버퍼링 계속 돌다 재시 도하 나오다 사용 좋다 어플  ...
#  '샤오미 비교 해보다 기능 한참 부족하다 공기청정기 예약 기능 단순 켜다 끄다 없다 모드 선택 안되다 나마 켜다 꺼지다 알람 오지 않다 가다 기술 없다 아니다 부족하다 수준 앱 제공 수 없다 의문 기기 가격 차 생각 더 더욱 그렇다 빠르다 발전 모습 기대 해보다케이블 시청 채널 변경 안되다 프로그램 그렇다 프로그램 오류 투성이 방금 알아내다 리모컨 가리키다 채 핸드폰 채널 변경 동작 거 버그 넘다 심해오류 발생 사용 횟수 나오다 않다 이메일 보내다 읽다 답 없다 자다 쓴다 넘다 주 쯤 전 알림 오다 용량 최근 사용 코스 가다 누락 확인 해주다 현재 정상 이용 가능하다 이메일 빠르다 답변 감사 드리다 해결 해주다 감사하다공기청정기 컨트롤 기능 제품 상태 보이 컨트롤 안 기능 추가 해주다 추가 공기 청정기 김치 냉장고 식기 세척 기 세탁기 건조기 사용 중 김치냉장고 온도 조절 안전 무관 쉬다 추가 가능하다 듯 식기 세척 기 건조기 사용자 동의 따르다 컨트롤 기능 사용 수 안 집 안 와이파이 연결 경우 컨트롤 위험성 없다 보이다청 기르다 제외 몇몇 제품 전원 켜다 연걀돼 격 제어 엘지 시스템 에어컨 아예 걀 방법 없다 삼성 스마트 즈 애플 시장 개발자 개발 자체 핸들러 사용 가능하다 기계 전원 오프 구글 어시스컨트 연결 가전 무조건 엘지 쓰다 연결 아쉽다실외 습도 가다 맞다 실외 습도 표시 부분 실내 습도 표시 실내 가다 습도계 나오다 어플 실외 습도 나오다 한겨울 비다 아니다 습도 나오다 리가문제점 파악 도움 쉬다 부분 좋다 해결 보고 지다 보다 차 고장원 발생 부분 보안 편리하다코스 끊다 앱 세탁기 연결 끊다 개선 해주다 들다 이불 코스 번 돌리다 헹굼 세기 틀리다 번 정도 더 돌리다 앱 세탁기 끊어지다 버리다 세탁기 가다 다시 스마트 연결 누르다 번거롭다 움 그게 가장 불편하다 세탁 끊다 앱 세탁기 연결 끊어지다 해주다업데이트 등록 제품 싹 사라지다 업데이트 초기 업데이트 목적 입 등록 귀찮다 엘지 기술 실망 엉망제품 모델 선택 따르다 소모품 부품 나오다 좋다 공기청정기 필터 일일이 선택 호환 모델 찾다 답답하다 전자제품 앱 프로그램 개선 시급하다 보이다세탁기 원격 가다 안되다 쓸모 없다 외부 못키 건가 퇴근 맞추다 세탁 끝내다 싶다 아침 출근길 파워 놓다 가면 전원 꺼지다 버리다 수동 격인 모르다 김치냉장고 기능 쓰다 모르다 숙성 모니터링 기능 건지다편하다 자다 사용 음성 기기 명령 내리다 방법 자다 모르다 공기청정기 쓰다 가끔 음성 명령 내리다 싶다 명령 시엔 설정 않다다운로드 코스 사용 내용 바뀌다 밉다 다운 받다 하니 번거롭다 겨울철 자주 사용 패딩 가죽 모피 류 기본 좋다대비 어플 사용 불편하다 세탁기 통 살균 시기 푸시 알람 오다 좋다 수동 확인 불편하다 격 제어 설정 부분 불편하다 수정 푸시 알림 켜다 알림 오다 세탁기 상 전원 연결 제품 아니다 원선 뽑다 끼우다 아니다 계속 플러그 꽂다 두다 않다 문제 세탁기 켜다 통 살균 시기 알다 주다 직접 세탁기 지원이 안되다 때문 어플 쓰다 기능 빼다 어플 필요하다패딩철 스타 이르다 연결하다 패딩 코스 다운 해도 연결 자체 안되다 자꾸 공유기 거리 멀다 가다 멀다 거리 몇번 을해 막히다가전 쓰다 가정 라면 집안 매우 유용하다 쓸다 수 앱 제한 격 제어 이기다 다운로드 코스 받다 유용하다 쓸다 수 차다 좋다 듯스타 이르다 사용 시 와이파이 비번 입력 해도 비밀번호 틀리다 뭔가 공유기 미터 옆 비번 맞다 뭐 가요세탁기 코스 세부 설정 비활 되어다 활 바꾸다 물 높이 세탁 헹굼 횟수 탈수 세기 조정 차다 좋다 안되다 리뷰 답변 되어다화면 면 양쪽 번갈아 검색 새롭다 기능 향상 경험 개발 팀 미래 기술 무궁 발전기 원하다 최춘식 올리다사용 수동 켜 놓다 야하다 말 꺼내다 마소 샤오미 반 따라가다대기업 만들다 어플 심각하다 느리다 불안정하다 이지나 개선 기다리다 금도 돼다 돼다 하니 처음 뒤엎 다시 만들다 야하다 개판 만들다 개선 불가 수준 거나 의지 없다 밉다 에어 쓰다 엘지 낫다 웬걸 샤오미 어플 쓰레기 어플서버 응답 없다 분 차례 문의 주신 거 답변 없다 부정 리뷰 일부러 답변 안주시 건지다 건조기 사태 소비자 답답하다 죽다 일말 대응 없다마흔 중반 넘다 증상 생기다 앱 인하다 제때 챙기다 되어다 점 좋다 별 빼다 이유 문 열다 주다 그렇다 시스템 변경 별 개 해 드리다최신 세탁기 사고 앱 깔다 연동 설명 펼치다 사용 방법 애플리케이션 도움말 보라 앱 실행 세탁기 와이파이 활성화 화면 넘어가다 않다 제품 등록 안되다 와이파이 검색 해보다 세탁기 처럼 보이다 이름 길다 뜨다 연결하다 보다 비밀번호 입력 하라 비밀번호 써다 뭐 어쩌 은지 앱 설명 번 과정 번 과정 넘어가다 비번 나오다 설정 거지같다 다가 포기 함효용 체감 않다 좀더 개선 필요하다 듯 유저 인터페이스 앱 디자인 실망 스럽다 움명의 사용자 동시 접속 활 용도 높아지다 제품 대해 단 사람 접속 활 용도세탁기 경우 다운로드 코스 세부 사항 정 수 좋다 아쉬움 소량 세탁 경우 헹굼 횟수 변경 수 없다 불편하다사용자 사용 뭘 조건 걸다 기술 해결 특수문자 안되다 기술 그대로 보여주다 차다 소프트웨어 약하다 엘지어플 완전 쓰레기 느리다 어플 켜다 공기청정기 전원 버튼 누르기 세월 걸리다 갤럭시 홈 미니 빅스 비 불다 켜 달라 백만배 빠르다좋다 격 제어 버튼 누르다 외출 밖 조정 가능 불편 글 행굼 탈수 온도 개별 조작 가능하다 해주다 좋다이렇다 머 저리 들이다 멀쩡하다 어플 업뎃 연결 안되다 만들다 진심 건조기 넘다 어플 업뎃 넘다 월급 아깝다앱 평 쓸다 정도 나중 식기세척기 앱 돌리다 날 오기 기대하다 점좋다 말로 아주 아쉽다 기분 말 쓰레기 앱 요 큐앱 연결하다 엘지 기기 총 개 식기세척기 레인지 연결 돼다 상태 창 나오다 않다 못 김치냉장고 공기청정기 세탁기 건조기 연결 해제 에어컨 개 정수기 정도 연결 안정 에어컨 오프 기능 빼다 딱하다 필요 없다 실망 스럽다거 올해 들다 갑자기 이르다 어제 저녁 들다 기전 폰 키 려고 계속 안되다 연결하다 다시 재 설정 글 오늘 다시 해보다 연결 안되다 스탠드 연결하다 놓다 벽 걸이 애 먹다 폰 끄다 켜 보고 로그아웃 몇번 대체 이르다 임 개선 해주다 폭염 덥다 죽다 작년 안 돈 버셨습 들다 관리 해 벽 걸이 에어컨 삭제 다시 추가 아예 연결 안되다 개선 해주다 작년 듀얼 스페셜 모델연결하다 표시 나오다 에어컨 외부 켜다 없다 한심하다 아예 기능 없다 얘 가격 하해 소비자 우롱 에어컨 사라지다 레인지 남다 새롭다 산 냉장고 아예 연결 시도 않다 고 진짜 개판 늘다 무늬 사물인터넷 줏 샤오미 삼성에어컨 예약 자주 세팅값 저장 기능 만들다 안 반응속도 더럽다 느리다 주제 인터페이스 구려 실행 짜증 솟구치다 애초 집 전자기기 컨트롤 엘지 서버 유해 야하다스마트 진단 가끔 사용 유용하다 냉장고 덜 닫히다 경고 해주다 식품 저장 등록 두다 사용 기한 알다 편리하다 세탁 알다 빨래 세탁기 안 숙성 일도 줄어들다 자주 잊다 많다 차다 도움 앱에어컨 경우 기능 후 켜다 끄다 냉방 송풍 바람 세기 절전 리모컨 세부 기능 조절 수기기 연결하다 사용 용기 만족하다 사용 개선 필요하다 부분 적다 보다 공기청정기 스타 이르다 건조기 티비 미세먼지 알 리미 연동 사용 불변 점 가지 첫째 공기청정기 접속 자다 끊기다 청정기 와이파이 접속 버튼 누르다 야하다 둘째 어플 메인 화면 제품 리스트 순서 변경 사용자 위주 개선 필요하다 스마트홈 어플 비교 은 보다 개선 필요하다사용 간단하다 그렇다 냉장고 사용 시 문 열리다 닫히다 않다 스마트 사이트 알림 푸다 쉬 없다 그리다 어렵다 않다 검토 부탁드리다김치냉장고 문 안 닫히다 알람 울리다 계속 열다 번 앱 속도 늦다 때문 짜증 알람 기능 감동공기청정기 연결하다 알림 설정 기질 알림 빈번 이력 보다 번 오기 분 간격 하루 밤새 번 반복 경우 알림 한번 발생 후 정도 간격 두다 후 기질 개선 않다 다시 알림 발생 맞다 않다 알림 받다 수면시간 제외 기능세탁기 격 제어 사용 좋다 어플 내 저장 되어다 설정 사용 수 아쉽다 디테일 부분 물 높이 빨래 헹굼 횟수 도 사용자 직접 설정 수 업데이트 부탁드리다 그렇다 않다 어플 세탁 완료 알람 받다 기능 사용 지우다 느낌 강 ...
#  '공기청정기 대모 컨트롤 안되다 등록 해제 다시 등록 와이파이 버튼 누르다 활성화 선 무 반응 공기청정기 깜빡 거리 데 어플 무 반응 노트 사용 스마트 네트워크 전환 해제 모바일 데이터 차단 오늘 서비스 센터 가지 가다 모듈 교체 비용 나오다 장비 문제 아니다 지인 인근 업다 들다 공기청정기 등록 고해 증상 요 고객 센터 통해 담당 부서 연결하다 토요일 연결 안되다 월요일 연결하다 부분 대해 콜센터 스마트 싱큐 담당자 서비스 센터 커뮤니케이션 진행 불필요하다 서비스 비용 노력 덜다 덕분 핸드폰 문제 알 초기 차다 짜증나다 댓글 고객 아이디 증상 적다 담당자 메일 보내다 달라 고하 말다 콜센터 접수 이력 증상 역 보시 연락 주다 나다코노 매장 에어컨 대다 연결하다 쓰다 어플 반응속도 빨르다 좋다 한가지 아쉽다 점 고객 센터 꼭 개발자 전달 해달라다 부탁드리다 일반 예약 다르다 반복 예약 꼭 켜지다 꺼지다 입력 반복 예약 상태 상관 꺼지다 예약 없다 지금 모든 에어컨 반복 예약 켜다 꺼지다 맞추다 두다 꼭 이렇다 방법 없다 나중 알아보다 안이 중소기업 어플 어플 켜지다 송풍 바람 세기 강 꺼지다 켜지다 냉방 도 켜지다 습 식 예약 상태 예약 큐 켜지다 꺼지다 안되다 완전하다 똑같다 않다 예약 상태 별 예약 켜지다 입력 않다 꺼지다 예약 반복 예약 되어다 좋다김치냉장고 고장 나서다 시원하다 않다 음식 썪 부르다 기사 원인 알아보다 보고 콤 프레 셔 고장 며칠 뒤 오기 감 나다 콤프레셔 고장 싶다 어플 깔다 스마트 진단 정상 메세지 뜸 고장 나서다 다시 방문 고장 스마트 진단 정상 메세지 스마트 진단 마나 엉망 진단 테스트 임에어컨 기준 주간 월간 일간 전력 소모 량 때문 보다 들어가다 번거롭다 느리다 패치 후 일간 그래프 별로 바뀌다 난잡하다 주간 월간 시안 더 떨어지다 점 점 말일 막대그래프 여개 보여주다 정도 모바일 사업 부 적자 붙잡다 안다 정작 가다 정확하다 지향 갈피 못자다 느낌 터치 해상도 스마트폰 조작 리모콘 깔끔하다 편하다 반대 원 최신 모델 임 그렇다예전 실외 기 온도 나오다 문안 열다 켜다 켜다 판단 가동 그냥 날씨 앱 동네 온도 나오다 섬 동네 그렇다 날씨 앱 정보 매우 매우 부 정확하다 들다 여름 한참 최고 기온 최저 기온 기상청 문의 하니 관측 장비 땅 문제 때문 산꼭대기 바탕 동네 예보 온도 표시 요 앱 받다 온도 현실 동떨어지다 온도 싱큐 실행 뜨다 큐 웨더 온도 뚱딴지 온도 꼭 일일 바깥 문 열다 보다 외부 온도 알다 예전 실외 기 온도 나오다 정확하다 않다 번 쓰다 보다 실쇠기 도 경험 에어컨 켜다 끄다 동네 신 동떨어지다 날씨 어플 온도 실지 실외 기 체크 도 온도 표시 다시 살리다 블루투스 항상 끄다 싱큐앱 켜다 자꾸 블루투스 활성화 앱 옵션 켜다 옵션 넣다냉장고 식품 관리 기능 굉장하다 불편하다 유통 기한 지정 연 단위 바꾸다 없다 직접 입력 수도 해주다 식품 추가 유통 기한 설정 수 좋다 추가 다시 목록 가다 일일이 설정 불편하다 아니다 폰 찍다 사물 인식 유통 기한 찍다 알다 입력 기능 추가 좋다건조기 연동 전 안되다 촤 버전 도 업뎃하 팝업 뜨다 주로 보다 가전 냉장 세탁 건조 사살 방향 소통 필요없다 가전 앱 역할 진행 상황 체크 정도 그렇다 어플 무겁다 도무지 노 이해 이렇다 개발 힘쓰다 만들다 버리다 두다 도대체 뭘 갖다 우기다 넣다 용량 버벅거림 넘다 속상하다 때리다 박다 생각 아니다 가볍다 해주다 막말 날씨 정보 관련 가전 때문 데이타 필요하다 자세하다 크게 보여주다 어플 깔다 정도 유저 잠그다 화면 위젯 노티 서든 최소한 앱 훨 좋다 본인 취향 해놧을건데 스띵개발팀 놈 날씨 안내 초창 기 간소화 끝내 버리다 기상청 날씨 아주 미세먼지 예일 선 앱 짱짱맨 넣다 넣다 해도 개발자 소신 신념 지키다 집 드럼 일체 문짝 터치 버튼 건조기 직렬 드럼 위 놓다 쓰다 종종 건조기 빨래 넣다 빼다 몸 세탁기 전원 건드리다 진행중 빨래 꺼지다 문제 코스 아니다 불리다 삶다 특별하다 걸 경우 세탁 탈수 꺼지다 평소 코스 경우 감다 잡히다 난감 자체 세탁기 뜯다 힘들다 뭐 꺼지다 알다 기능 개발 해주다 좋다 정상 완료 나중 보여주다 앱 코스 상세 설정 얘기 알림 진동 소리 가전 별로 선택 가능하다 괜찮다 반복 기능 세탁기 건조기 니즈 건조기 뭐 해결 집 지원 물건 도 충돌 일어나고 난리 임 걔 업뎃하 빨래 길다 써다 버리다 경쟁 앱 덜 구려 세탁기 어르다 문안 갇히다 상태 돌아가다 원격 세탁기 자체 못키 않다 법 알다 달 주시 분 그리다 상냥하다 전원 요청 전 달다 하나요 법 안되다 법 바뀌다 가요 댓글러 빈말 남발 가요 잘못 알 가요 우리나라 유럽 안되다 거자다 쓰다 날 업데이트 갑자기 스탠드 에어컨 벽 걸이 에어컨 냉장고 드럼세탁기 미니 세탁기 건조기 싹 연결 해제 후 재 등록 어플 삭제 짓 다해 연결 불가 마지막 계정 바꾸다 이전 네이버 연동 구글 연동 해보다 연결 성공 유추 해보다 신규 등록 로직 기존 서버 등록 되어다 유저 정보 클라이언트 단 오류로 인하다 재 등록 시도 경우 업데이트 부분 로직 오류 서버 등록 되어다 유저 기기 상태 값 정상 클라이언트 단 어떠하다 유로 정상 인증 루트 재 등록 요청 경우 기존 정보 삭제 후 이력 남다 신규 등록 절차 진행 식 로직 변경 필요하다 보임결론 가전제품 스마트 큐 접속 불가 상황 결론 앱 문제 함 서버 문제 며칠 짓 다해 가다 새벽 불 터지다 오늘 엘지 고객 서비스 개선 건의 사항 올리다 문의 결과 앱 연결 서버 문제 함 며칠 생쇼 짓 다한 거 생각 분통 터지다 와이파이 회선 점검 별 짓거리 로봇청소기 매핑 다시 바닥 짐 들어오다 려 거 보 통일 아니다 앱 지우다 깔다 미치다 짓다 모든 정보 나르다 새롭다 매핑 청소 금지 구역 설정 하루 날 잡다 정말 짜증나다 엘지 처음 서버 문제 뭐 공지 해주다 복구 예정 등록 기기 삭제 앱 다시 깔다 미치다 짓 그대로 기다리다 보다 식 처리 게 정말 화가 남 엘지 가전 자다 만들다 생각 스마트 큐 건만 보다 갈다 길이 멀다 불로봇청소기 업그레이드 시 네트워크 종료 되어다 업그레이드 안되다 은 청소기 초기 후 설정 메뉴 들어가다 업그레이드 청소 도면 다시 사용 하니 일부 아이콘 터치 안되다 문제점 와이파이 자꾸 끊어지다 예전 절전 모드 시 와이파이 살다 앱 절전 모드 해재 격 제어 가능하다 업그레이드 후 절전 모드 손 해제 뭘 업그레이드 건지다 모르다 내용 대한 안내 없다 비싸다 제품 상실 다운 그레이드 하나요냉장고 그냥 냉장 냉동 구분 되어다 더 세분 냉장고 별 짝별 냉동 실 냉장 실 위아래 세분 음식 간단하다 알 수 냉장고 별 세분 복잡하다 소비자 세분 작성 수 인터페이스 개선 쓸다 웨어 것임 분발이렇다 글 올리다 개발자 입장 매우 기분 나쁘다 사용자 입장 가지 올리다 보다 어플 자체 자다 만들다 벌레 퇴치 확실하다 해 두다 아쉽다 점 간단명료 한눈 아이콘 보이다 기능 좋다 간단하다 오프 유무 정도 보이 표시 상세 정보 탭해 기존 보여주다 방식 작동 좋다 아이콘 뷰 카드 뷰 선택 줌 줌 아웃 조절 방식 아이콘 뷰 오프 기능 길다 누르다 실행 방식 구현 더블탭 나다 겁니다 가다 새롭다 문구 쫌 보이다 좋다 그냥 외부 기상 정보 나오다 설정 되어다 아예 제거 좋다 부분 손가락 가다 보아 정보 더 보 카드 방식 사용 문제 없다 많다 생각 듭니로봇청소기 방 마다 이름 붙이다 인공 지능 스피커 크다 바 음성 특정 방 청소 좋다 전체 아니다 부방 청소 꼭앱 켜다 불편하다 특정 부분 청소 리모콘 이동 야하다 앱 특정 부위 찍다 보내다 음성 해당 방 이동 후 집중 청소 좋다지역 언어 고정 유럽 한국 사람 사다 유럽 다국적 섞이다 살다 지역 따르다 언어 고정 선택 해주다 맞다 메뉴얼 워런 티 카드 보다 유럽 언어 들어가다 한글 없다 한국말 쓰다 어렵다 유럽 한국 사람 살 국뽕 취해 국산 살다 사람 더 그렇다 쪼럽 좋다 방향 업데이트 되어다 바램 보다 평가 감사하다밑 대다수 리뷰 의견 세탁기 건조기 원격 오프 안되다 불편 사항 말씀드리다 답변 해주다 보다 반려동물 때문 제한 게말 안되다 원격 직접 조작 간 코스 작동 위 세탁기 건조기 도어 기본 닫히다 작동 도어락 걸리다 압니 도어 열리다 코스 작동시키다 당연하다 돌아가다 ...

# %% [markdown]
# ### 5.2 데이터프레임으로 만들고 정렬하기
#
# - C TF-IDF : 군집별 단어 빈도

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_document)

# 각 단어와 TF-IDF 값을 확인
feature_names = vectorizer.get_feature_names_out()
dense = tfidf_matrix.todense()
tf_idf_df = pd.DataFrame(dense, columns=feature_names)
#행과 열 변환
tf_idf_df_transposed = tf_idf_df.T
tf_idf_df_transposed.head()
# Out:
#               0         1         2         3         4    5
# 가게     0.000000  0.000000  0.002131  0.002132  0.000000  0.0
# 가격     0.000000  0.002774  0.007197  0.000000  0.013870  0.0
# 가구     0.000000  0.000000  0.000000  0.002600  0.000000  0.0
# 가기     0.000000  0.005549  0.000000  0.001800  0.004623  0.0
# 가까워지다  0.011433  0.000000  0.000000  0.000000  0.000000  0.0

# %%
for i in tqdm(tf_idf_df_transposed.columns):

    #tfidf 높은 순부터 정렬하기
    tf_idf_data = tf_idf_df_transposed[i].sort_values(ascending=False)

    # 정렬한 데이터 딕셔너리로 만들기
    data = {'word':tf_idf_data.index, 'tf-idf': tf_idf_data.values}
    data_df = pd.DataFrame(data)

    #딕셔너리로 만든 데이터 df에 자동 저장
    # data_df.to_csv('Cluster{}_tf-idf.csv'.format(i), encoding='utf-8-sig')
    print("="*10 + f" 군집 {i} " + "="*10)

    print(data_df.head(15))
    print()
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 409.67it/s]
# ========== 군집 0 ==========
#    word    tf-idf
# 0   안되다  0.263903
# 1    사용  0.263903
# 2    기능  0.238528
# 3    연결  0.213153
# 4    어플  0.182702
# 5    없다  0.177627
# 6    제품  0.172552
# 7    제어  0.147177
# 8   에어컨  0.147177
# 9    보다  0.131952
# 10   좋다  0.131952
# 11   전원  0.121801
# 12   알림  0.121801
# 13   등록  0.111651
# 14   켜다  0.106576
#
# ========== 군집 1 ==========
#    word    tf-idf
# 0   안되다  0.377130
# 1    연결  0.332657
# 2    사용  0.305973
# 3    등록  0.183228
# 4   에어컨  0.177891
# 5    없다  0.168997
# 6    켜다  0.167218
# 7    좋다  0.165439
# 8    제품  0.161881
# 9    자다  0.158323
# 10   기능  0.154766
# 11  건조기  0.129861
# 12  세탁기  0.124524
# 13   제어  0.124524
# 14   쓰다  0.115629
#
# ========== 군집 2 ==========
#     word    tf-idf
# 0    안되다  0.404944
# 1     연결  0.369180
# 2     등록  0.260733
# 3    에어컨  0.215739
# 4     제품  0.211125
# 5     어플  0.192666
# 6     사용  0.177668
# 7     없다  0.156901
# 8     다시  0.155748
# 9   와이파이  0.145365
# 10    뜨다  0.125752
# 11    않다  0.117676
# 12    자다  0.116522
# 13    좋다  0.106139
# 14    서버  0.105191
#
# ========== 군집 3 ==========
#     word    tf-idf
# 0    안되다  0.400535
# 1     연결  0.386683
# 2     사용  0.294341
# 3     등록  0.250478
# 4     제품  0.222776
# 5     좋다  0.182376
# 6     기능  0.175450
# 7     자다  0.167370
# 8     없다  0.155828
# 9     어플  0.148902
# 10   에어컨  0.148902
# 11  와이파이  0.125816
# 12    뜨다  0.110811
# 13    확인  0.107909
# 14    켜다  0.102731
#
# ========== 군집 4 ==========
#     word    tf-idf
# 0    안되다  0.314234
# 1     연결  0.284589
# 2     사용  0.207513
# 3     기능  0.204548
# 4    에어컨  0.204548
# 5     어플  0.183797
# 6     없다  0.177868
# 7     쓰다  0.168975
# 8     등록  0.166010
# 9     제품  0.148224
# 10    않다  0.142295
# 11    좋다  0.136366
# 12    켜다  0.133401
# 13  와이파이  0.127472
# 14   만들다  0.127472
#
# ========== 군집 5 ==========
#     word    tf-idf
# 0     연결  0.215233
# 1     어플  0.198015
# 2     없다  0.198015
# 3     제품  0.163577
# 4    안되다  0.154968
# 5     등록  0.146359
# 6     문제  0.129140
# 7   와이파이  0.120531
# 8     좋다  0.120531
# 9     사용  0.120531
# 10    보다  0.120531
# 11   꺼지다  0.111921
# 12   스마트  0.111921
# 13   세탁기  0.111921
# 14    코스  0.111921
